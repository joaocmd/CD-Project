# %%
from data import *
from strategies import *
from dtree import *

# %% [markdown]
# # Heart Failure Dataset

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# ### Raw

# %%
# res = decisionTrees(get_hf_data(filter_outliers=True, feature_selection=False), 'DEATH_EVENT')
best_tree = dtree(get_hf_data(feature_selection=True), 'DEATH_EVENT')
# Out:
# Best results achieved with entropy criteria, depth=2 and min_impurity_decrease=0.025 ==> accuracy=0.831

# %% [markdown]
# ### Undersample

# %%
res = dtree(get_hf_data(filter_outliers=True, feature_selection=True), 'DEATH_EVENT',balancing='undersample')
# Out:
# Best results achieved with gini criteria, depth=5 and min_impurity_decrease=0.025 ==> accuracy=0.821

# %% [markdown]
# ### SMOTE

# %%
res = dtree(get_hf_data(feature_selection=True), 'DEATH_EVENT',balancing='smote')
# Out:
# Best results achieved with entropy criteria, depth=2 and min_impurity_decrease=0.025 ==> accuracy=0.831

# %% [markdown]
# ### Oversample

# %%
res = dtree(get_hf_data(feature_selection=True), 'DEATH_EVENT',balancing='oversample')
# Out:
# Best results achieved with entropy criteria, depth=2 and min_impurity_decrease=0.025 ==> accuracy=0.831

# %% [markdown]
# # Toxicity Dataset

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# ### No balancing

# %%
res = decisionTrees(get_t_data(), 'toxic', quick=True, kfold=False)
# Out:
# ...
#   0%|          | 0/5 [00:00<?, ?it/s]
# Best results achieved with entropy criteria, depth=10 and min_impurity_decrease=0.001 ==> accuracy=0.931
# 100%|██████████| 5/5 [00:02<00:00,  1.81it/s]

# %% [markdown]
# ### Undersample

# %%
res = decisionTrees(get_t_data(), 'toxic', quick=True, kfold=False, balancing='undersample')
# Out:
# ...
#   0%|          | 0/5 [00:00<?, ?it/s]
# Best results achieved with gini criteria, depth=2 and min_impurity_decrease=0.025 ==> accuracy=0.835
# 100%|██████████| 5/5 [00:00<00:00, 11.65it/s]

# %% [markdown]
# ### Oversample

# %%
res = decisionTrees(get_t_data(), 'toxic', quick=True, kfold=False, balancing='oversample')
# Out:
# ...
#   0%|          | 0/5 [00:00<?, ?it/s]
# Best results achieved with gini criteria, depth=5 and min_impurity_decrease=0.001 ==> accuracy=0.885
# 100%|██████████| 5/5 [00:04<00:00,  1.12it/s]

# %% [markdown]
# ### SMOTE

# %%
res = decisionTrees(get_t_data(), 'toxic', quick=True, kfold=False, balancing='smote')
# Out:
# ...
#   0%|          | 0/5 [00:00<?, ?it/s]
# Best results achieved with entropy criteria, depth=10 and min_impurity_decrease=0.001 ==> accuracy=0.911
# 100%|██████████| 5/5 [00:04<00:00,  1.06it/s]
