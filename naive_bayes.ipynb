# %%
from strategiesavg import *
from data import *
import matplotlib.pyplot as plt

# Raw
d0 = get_hf_data()
# Outliers
d1 = get_hf_data(filter_outliers=True)
# Scaling
d2 = get_hf_data(scaling='z-score')
d3 = get_hf_data(scaling='minmax')
# Outliers and scaling
d4 = get_hf_data(filter_outliers=True, scaling='z-score')
d5 = get_hf_data(filter_outliers=True, scaling='minmax')

dfs = [d0,d1,d2,d3,d4,d5]
balancings = [None, 'undersample', 'oversample', 'smote']

# %%
best = ("", 0)

for i, df in enumerate(dfs):
    for bal in balancings:
        if (i == 4 or i == 2): continue
        print("Index: ", i, "balancing:", bal)
        params, results = NaiveBayesKFold(df, "DEATH_EVENT", balancing=bal)
        accuracy = results["Accuracy"][1]
        print(f'Accuracy: {accuracy:.2f}')
        print(f'Params: {params}')
        plt.pause(0.1)
        print("Results:", results)
        print("\n------\n\n")
        if (accuracy > best[1]):
            if bal == None: bal = "None"
            best = (str(i) + "," + bal, accuracy)
            
print(best)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 393.04it/s]
# 100%|██████████| 3/3 [00:00<00:00, 517.92it/s]
# 100%|██████████| 3/3 [00:00<00:00, 625.89it/s]
# 100%|██████████| 3/3 [00:00<00:00, 502.07it/s]
# 100%|██████████| 3/3 [00:00<00:00, 580.34it/s]
# Index:  0 balancing: None
# Accuracy: 0.75
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 153.72it/s]
# 100%|██████████| 3/3 [00:00<00:00, 330.62it/s]
# 100%|██████████| 3/3 [00:00<00:00, 438.06it/s]
# 100%|██████████| 3/3 [00:00<00:00, 449.86it/s]
# 100%|██████████| 3/3 [00:00<00:00, 463.37it/s]
# Results: {'Accuracy': [0.8319072524407253, 0.7489265536723164], 'Recall': [0.9458153449973491, 0.8658536585365854], 'Specificity': [0.5914217361585783, 0.49473684210526314], 'Precision': [0.8319011251820599, 0.8199143956176052]}
#
# ------
#
#
# Index:  0 balancing: undersample
# Accuracy: 0.72
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 231.94it/s]
# 100%|██████████| 3/3 [00:00<00:00, 292.54it/s]
# 100%|██████████| 3/3 [00:00<00:00, 300.04it/s]
# 100%|██████████| 3/3 [00:00<00:00, 292.35it/s]
# 100%|██████████| 3/3 [00:00<00:00, 262.70it/s]
# Results: {'Accuracy': [0.7916438824333561, 0.7222598870056497], 'Recall': [0.8591934381408065, 0.7415853658536585], 'Specificity': [0.7240943267259057, 0.6736842105263158], 'Precision': [0.7620292023138465, 0.8802284657414918]}
#
# ------
#
#
# Index:  0 balancing: oversample
# Accuracy: 0.75
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 111.89it/s]
# 100%|██████████| 3/3 [00:00<00:00, 265.03it/s]
# 100%|██████████| 3/3 [00:00<00:00, 370.22it/s]
# 100%|██████████| 3/3 [00:00<00:00, 379.76it/s]
# 100%|██████████| 3/3 [00:00<00:00, 371.32it/s]
# Results: {'Accuracy': [0.8120730137090055, 0.7489265536723164], 'Recall': [0.8768461713246989, 0.7813414634146342], 'Specificity': [0.7472998560933122, 0.6736842105263158], 'Precision': [0.7811428653716476, 0.8805374959215565]}
#
# ------
#
#
# Index:  0 balancing: smote
# Accuracy: 0.73
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 176.35it/s]
# 100%|██████████| 3/3 [00:00<00:00, 398.00it/s]
# 100%|██████████| 3/3 [00:00<00:00, 456.18it/s]
# 100%|██████████| 3/3 [00:00<00:00, 601.45it/s]
# 100%|██████████| 3/3 [00:00<00:00, 567.74it/s]
# Results: {'Accuracy': [0.809634174051352, 0.7322598870056497], 'Recall': [0.8435507081723851, 0.7371951219512195], 'Specificity': [0.7757176399303188, 0.7157894736842105], 'Precision': [0.7914601561367892, 0.8956725854183482]}
#
# ------
#
#
# Index:  1 balancing: None
# Accuracy: 0.77
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 122.42it/s]
# 100%|██████████| 3/3 [00:00<00:00, 257.80it/s]
# 100%|██████████| 3/3 [00:00<00:00, 344.61it/s]
# 100%|██████████| 3/3 [00:00<00:00, 386.62it/s]
# 100%|██████████| 3/3 [00:00<00:00, 399.75it/s]
# Results: {'Accuracy': [0.8533273556586488, 0.7739348370927318], 'Recall': [0.9273068757145191, 0.8412820512820512], 'Specificity': [0.6867494824016563, 0.6130718954248366], 'Precision': [0.8707311915607924, 0.8672135047764338]}
#
# ------
#
#
# Index:  1 balancing: undersample
# Accuracy: 0.71
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 93.36it/s]
# 100%|██████████| 3/3 [00:00<00:00, 307.75it/s]
# 100%|██████████| 3/3 [00:00<00:00, 324.35it/s]
# 100%|██████████| 3/3 [00:00<00:00, 353.38it/s]
# 100%|██████████| 3/3 [00:00<00:00, 357.68it/s]
# Results: {'Accuracy': [0.8118012422360249, 0.7109022556390977], 'Recall': [0.8105175983436853, 0.7034615384615385], 'Specificity': [0.8130848861283644, 0.7176470588235294], 'Precision': [0.8128844233345512, 0.9051298701298701]}
#
# ------
#
#
# Index:  1 balancing: oversample
# Accuracy: 0.71
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 113.40it/s]
# 100%|██████████| 3/3 [00:00<00:00, 244.24it/s]
# 100%|██████████| 3/3 [00:00<00:00, 345.62it/s]
# 100%|██████████| 3/3 [00:00<00:00, 363.31it/s]
# 100%|██████████| 3/3 [00:00<00:00, 362.53it/s]
# Results: {'Accuracy': [0.7990854156459253, 0.7075187969924812], 'Recall': [0.8175975828842071, 0.703076923076923], 'Specificity': [0.7805732484076433, 0.7065359477124182], 'Precision': [0.7892771089628098, 0.8959090909090909]}
#
# ------
#
#
# Index:  1 balancing: smote
# Accuracy: 0.72
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 369.42it/s]
# 100%|██████████| 3/3 [00:00<00:00, 214.36it/s]
# 100%|██████████| 3/3 [00:00<00:00, 364.28it/s]
# 100%|██████████| 3/3 [00:00<00:00, 439.47it/s]
# 100%|██████████| 3/3 [00:00<00:00, 585.14it/s]
# Results: {'Accuracy': [0.809276498448473, 0.7180451127819548], 'Recall': [0.7805569165441777, 0.7033333333333334], 'Specificity': [0.8379960803527683, 0.7418300653594772], 'Precision': [0.8288571276147231, 0.9101948051948052]}
#
# ------
#
#
# Index:  3 balancing: None
# Accuracy: 0.76
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 166.66it/s]
# 100%|██████████| 3/3 [00:00<00:00, 333.81it/s]
# 100%|██████████| 3/3 [00:00<00:00, 320.04it/s]
# 100%|██████████| 3/3 [00:00<00:00, 475.94it/s]
# 100%|██████████| 3/3 [00:00<00:00, 438.03it/s]
# Results: {'Accuracy': [0.8009728033472803, 0.762316384180791], 'Recall': [0.9223812769825039, 0.8910975609756098], 'Specificity': [0.5446343130553657, 0.4842105263157895], 'Precision': [0.8116545966632289, 0.8125295680619948]}
#
# ------
#
#
# Index:  3 balancing: undersample
# Accuracy: 0.75
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 125.06it/s]
# 100%|██████████| 3/3 [00:00<00:00, 200.96it/s]
# 100%|██████████| 3/3 [00:00<00:00, 218.91it/s]
# 100%|██████████| 3/3 [00:00<00:00, 218.78it/s]
# 100%|██████████| 3/3 [00:00<00:00, 318.77it/s]
# Results: {'Accuracy': [0.7996411483253588, 0.7489830508474576], 'Recall': [0.9219412166780587, 0.8367073170731707], 'Specificity': [0.6773410799726589, 0.5578947368421052], 'Precision': [0.7455636470454712, 0.829911710811261]}
#
# ------
#
#
# Index:  3 balancing: oversample
# Accuracy: 0.74
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 144.19it/s]
# 100%|██████████| 3/3 [00:00<00:00, 292.00it/s]
# 100%|██████████| 3/3 [00:00<00:00, 326.13it/s]
# 100%|██████████| 3/3 [00:00<00:00, 259.51it/s]
# 100%|██████████| 3/3 [00:00<00:00, 255.73it/s]
# Results: {'Accuracy': [0.8010641520866469, 0.7389830508474576], 'Recall': [0.8879497083996062, 0.8365853658536585], 'Specificity': [0.7141785957736878, 0.5263157894736842], 'Precision': [0.7601220163196827, 0.8251864147613948]}
#
# ------
#
#
# Index:  3 balancing: smote
# Accuracy: 0.75
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 255.71it/s]
# 100%|██████████| 3/3 [00:00<00:00, 252.20it/s]
# 100%|██████████| 3/3 [00:00<00:00, 337.66it/s]
# 100%|██████████| 3/3 [00:00<00:00, 400.78it/s]
# 100%|██████████| 3/3 [00:00<00:00, 373.65it/s]
# Results: {'Accuracy': [0.8040824055138984, 0.7489830508474576], 'Recall': [0.8891464061198212, 0.8165853658536585], 'Specificity': [0.7190184049079754, 0.6], 'Precision': [0.7622756658091508, 0.8460262725779967]}
#
# ------
#
#
# Index:  5 balancing: None
# Accuracy: 0.69
# Params: MultinomialNB
# 100%|██████████| 3/3 [00:00<00:00, 326.72it/s]
# 100%|██████████| 3/3 [00:00<00:00, 306.13it/s]
# 100%|██████████| 3/3 [00:00<00:00, 394.61it/s]
# 100%|██████████| 3/3 [00:00<00:00, 471.15it/s]
# 100%|██████████| 3/3 [00:00<00:00, 448.16it/s]
# Results: {'Accuracy': [0.6875114105629211, 0.686512928022362], 'Recall': [0.9986206896551724, 1.0], 'Specificity': [0.040248447204968944, 0.03333333333333333], 'Precision': [0.6841077499697713, 0.6830457453098963]}
#
# ------
#
#
# Index:  5 balancing: undersample
# Accuracy: 0.64
# Params: MultinomialNB
# 100%|██████████| 3/3 [00:00<00:00, 134.75it/s]
# 100%|██████████| 3/3 [00:00<00:00, 279.73it/s]
# 100%|██████████| 3/3 [00:00<00:00, 288.75it/s]
# 100%|██████████| 3/3 [00:00<00:00, 355.29it/s]
# 100%|██████████| 3/3 [00:00<00:00, 207.99it/s]
# Results: {'Accuracy': [0.7184057971014493, 0.6389937106918239], 'Recall': [0.7472877846790891, 0.6900900900900901], 'Specificity': [0.6895238095238095, 0.5228758169934641], 'Precision': [0.706790176959191, 0.7695656252931795]}
#
# ------
#
#
# Index:  5 balancing: oversample
# Accuracy: 0.65
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 208.12it/s]
# 100%|██████████| 3/3 [00:00<00:00, 209.68it/s]
# 100%|██████████| 3/3 [00:00<00:00, 279.14it/s]
# 100%|██████████| 3/3 [00:00<00:00, 238.16it/s]
# 100%|██████████| 3/3 [00:00<00:00, 287.89it/s]
# Results: {'Accuracy': [0.7465038314176246, 0.6534591194968553], 'Recall': [0.7609674329501915, 0.6788288288288289], 'Specificity': [0.7320402298850575, 0.5888888888888889], 'Precision': [0.7393945895325474, 0.8434304825609173]}
#
# ------
#
#
# Index:  5 balancing: smote
# Accuracy: 0.63
# Params: MultinomialNB
# Results: {'Accuracy': [0.7271599616858238, 0.6315863032844165], 'Recall': [0.7278352490421456, 0.7181681681681682], 'Specificity': [0.7264846743295019, 0.4444444444444444], 'Precision': [0.7268887018166443, 0.7473302478263442]}
#
# ------
#
#
# ('1,None', 0.7739348370927318)
