# %%
from strategiesavg import *
from data import *
import matplotlib.pyplot as plt

# Raw
d0 = get_hf_data()
# Outliers
d1 = get_hf_data(filter_outliers=True)
# Scaling
d2 = get_hf_data(scaling='z-score')
d3 = get_hf_data(scaling='minmax')
# Outliers and scaling
d4 = get_hf_data(filter_outliers=True, scaling='z-score')
d5 = get_hf_data(filter_outliers=True, scaling='minmax')

dfs = [d0,d1,d2,d3,d4,d5]
balancings = [None, 'undersample', 'oversample', 'smote']

# %%
best = ("", 0)

for i, df in enumerate(dfs):
    for bal in balancings:
        if (i == 4 or i == 2): continue
        print("Index: ", i, "balancing:", bal)
        params, results = NaiveBayesKFold(df, "DEATH_EVENT", balancing=bal)
        accuracy = results["Accuracy"][1]
        print(f'Accuracy: {accuracy:.2f}')
        print(f'Params: {params}')
        plt.pause(0.1)
        print("Results:", results)
        print("\n------\n\n")
        if (accuracy > best[1]):
            if bal == None: bal = "None"
            best = (str(i) + "," + bal, accuracy)
            
print(best)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 212.27it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 204.86it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 104.56it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 123.79it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 152.46it/s]
# Index:  0 balancing: None
# Accuracy: 0.68
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 97.97it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 93.43it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 90.51it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8708333333333333, 0.6779661016949152], 'Recall': [0.9325153374233128, 1.0], 'Specificity': [0.7402597402597403, 0.0], 'Precision': [0.8837209302325582, 0.6779661016949152]}
#
# ------
#
#
# Index:  0 balancing: undersample
# 100%|██████████| 3/3 [00:00<00:00, 57.01it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 83.19it/s]
# Accuracy: 0.68
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 120.19it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 116.84it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 131.36it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 94.80it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 187.24it/s]
# Results: {'Accuracy': [0.8636363636363636, 0.6779661016949152], 'Recall': [0.8571428571428571, 1.0], 'Specificity': [0.8701298701298701, 0.0], 'Precision': [0.868421052631579, 0.6779661016949152]}
#
# ------
#
#
# Index:  0 balancing: oversample
# Accuracy: 0.68
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 154.50it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 113.00it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 84.72it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 89.40it/s]
# Results: {'Accuracy': [0.8926380368098159, 0.6779661016949152], 'Recall': [0.9141104294478528, 1.0], 'Specificity': [0.8711656441717791, 0.0], 'Precision': [0.8764705882352941, 0.6779661016949152]}
#
# ------
#
#
# Index:  0 balancing: smote
# 100%|██████████| 3/3 [00:00<00:00, 95.17it/s]
# Accuracy: 0.68
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 198.22it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 120.89it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 144.51it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 373.92it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 108.29it/s]
# Results: {'Accuracy': [0.8895705521472392, 0.6779661016949152], 'Recall': [0.8957055214723927, 1.0], 'Specificity': [0.8834355828220859, 0.0], 'Precision': [0.8848484848484849, 0.6779661016949152]}
#
# ------
#
#
# Index:  1 balancing: None
# Accuracy: 0.71
# Params: MultinomialNB
# 100%|██████████| 3/3 [00:00<00:00, 148.99it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 119.98it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 143.47it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 132.88it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 201.69it/s]
# Results: {'Accuracy': [0.748898678414097, 0.7142857142857143], 'Recall': [0.7452229299363057, 1.0], 'Specificity': [0.7571428571428571, 0.058823529411764705], 'Precision': [0.8731343283582089, 0.7090909090909091]}
#
# ------
#
#
# Index:  1 balancing: undersample
# Accuracy: 0.70
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 122.39it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 104.19it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 185.03it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 91.11it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.9071428571428571, 0.6964285714285714], 'Recall': [0.8857142857142857, 1.0], 'Specificity': [0.9285714285714286, 0.0], 'Precision': [0.9253731343283582, 0.6964285714285714]}
#
# ------
#
#
# Index:  1 balancing: oversample
# 100%|██████████| 3/3 [00:00<00:00, 124.49it/s]
# Accuracy: 0.70
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 90.35it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 113.56it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 103.12it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8535031847133758, 0.6964285714285714], 'Recall': [0.8343949044585988, 1.0], 'Specificity': [0.8726114649681529, 0.0], 'Precision': [0.8675496688741722, 0.6964285714285714]}
#
# ------
#
#
# Index:  1 balancing: smote
# 100%|██████████| 3/3 [00:00<00:00, 66.50it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 91.34it/s]
#  33%|███▎      | 1/3 [01:40<03:20, 100.30s/it]
# Accuracy: 0.70
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 194.01it/s]
# 100%|██████████| 3/3 [00:00<00:00, 177.42it/s]
# 100%|██████████| 3/3 [00:00<00:00, 251.27it/s]
# 100%|██████████| 3/3 [00:00<00:00, 178.09it/s]
# 100%|██████████| 3/3 [00:00<00:00, 287.95it/s]
# Results: {'Accuracy': [0.8630573248407644, 0.6964285714285714], 'Recall': [0.8280254777070064, 1.0], 'Specificity': [0.8980891719745223, 0.0], 'Precision': [0.8904109589041096, 0.6964285714285714]}
#
# ------
#
#
# Index:  3 balancing: None
# Accuracy: 0.69
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 153.43it/s]
# 100%|██████████| 3/3 [00:00<00:00, 230.42it/s]
# 100%|██████████| 3/3 [00:00<00:00, 198.82it/s]
# 100%|██████████| 3/3 [00:00<00:00, 171.88it/s]
# 100%|██████████| 3/3 [00:00<00:00, 191.59it/s]
# Results: {'Accuracy': [0.8375, 0.6949152542372882], 'Recall': [0.9325153374233128, 1.0], 'Specificity': [0.6363636363636364, 0.05263157894736842], 'Precision': [0.8444444444444444, 0.6896551724137931]}
#
# ------
#
#
# Index:  3 balancing: undersample
# Accuracy: 0.69
# Params: MultinomialNB
# 100%|██████████| 3/3 [00:00<00:00, 165.11it/s]
# 100%|██████████| 3/3 [00:00<00:00, 205.43it/s]
# 100%|██████████| 3/3 [00:00<00:00, 182.44it/s]
# 100%|██████████| 3/3 [00:00<00:00, 158.59it/s]
# 100%|██████████| 3/3 [00:00<00:00, 97.56it/s]
# Results: {'Accuracy': [0.8441558441558441, 0.6949152542372882], 'Recall': [0.8571428571428571, 1.0], 'Specificity': [0.8311688311688312, 0.05263157894736842], 'Precision': [0.8354430379746836, 0.6896551724137931]}
#
# ------
#
#
# Index:  3 balancing: oversample
# Accuracy: 0.69
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 264.85it/s]
# 100%|██████████| 3/3 [00:00<00:00, 202.75it/s]
# 100%|██████████| 3/3 [00:00<00:00, 136.19it/s]
# 100%|██████████| 3/3 [00:00<00:00, 139.85it/s]
# 100%|██████████| 3/3 [00:00<00:00, 135.89it/s]
# Results: {'Accuracy': [0.8558282208588958, 0.6949152542372882], 'Recall': [0.9079754601226994, 1.0], 'Specificity': [0.803680981595092, 0.05263157894736842], 'Precision': [0.8222222222222222, 0.6896551724137931]}
#
# ------
#
#
# Index:  3 balancing: smote
# Accuracy: 0.69
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 179.92it/s]
# 100%|██████████| 3/3 [00:00<00:00, 368.33it/s]
# 100%|██████████| 3/3 [00:00<00:00, 339.84it/s]
# 100%|██████████| 3/3 [00:00<00:00, 326.14it/s]
# 100%|██████████| 3/3 [00:00<00:00, 349.97it/s]
# Results: {'Accuracy': [0.8742331288343558, 0.6949152542372882], 'Recall': [0.9141104294478528, 1.0], 'Specificity': [0.8343558282208589, 0.05263157894736842], 'Precision': [0.8465909090909091, 0.6896551724137931]}
#
# ------
#
#
# Index:  5 balancing: None
# Accuracy: 0.68
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 209.75it/s]
# 100%|██████████| 3/3 [00:00<00:00, 224.31it/s]
# 100%|██████████| 3/3 [00:00<00:00, 124.76it/s]
# 100%|██████████| 3/3 [00:00<00:00, 116.23it/s]
# 100%|██████████| 3/3 [00:00<00:00, 122.03it/s]
# Results: {'Accuracy': [0.8418604651162791, 0.6792452830188679], 'Recall': [0.8896551724137931, 1.0], 'Specificity': [0.7428571428571429, 0.0], 'Precision': [0.8775510204081632, 0.6792452830188679]}
#
# ------
#
#
# Index:  5 balancing: undersample
# Accuracy: 0.70
# Params: MultinomialNB
#   0%|          | 0/3 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.7357142857142858, 0.6981132075471698], 'Recall': [0.7285714285714285, 1.0], 'Specificity': [0.7428571428571429, 0.058823529411764705], 'Precision': [0.7391304347826086, 0.6923076923076923]}
#
# ------
#
#
# Index:  5 balancing: oversample
# 100%|██████████| 3/3 [00:00<00:00, 17.73it/s]
# 100%|██████████| 3/3 [00:00<00:00, 123.70it/s]
# 100%|██████████| 3/3 [00:00<00:00, 231.71it/s]
# 100%|██████████| 3/3 [00:00<00:00, 217.99it/s]
# 100%|██████████| 3/3 [00:00<00:00, 181.76it/s]
# Accuracy: 0.70
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 129.26it/s]
# 100%|██████████| 3/3 [00:00<00:00, 179.86it/s]
# 100%|██████████| 3/3 [00:00<00:00, 228.86it/s]
# 100%|██████████| 3/3 [00:00<00:00, 292.03it/s]
# 100%|██████████| 3/3 [00:00<00:00, 150.97it/s]
# Results: {'Accuracy': [0.8103448275862069, 0.6981132075471698], 'Recall': [0.7931034482758621, 1.0], 'Specificity': [0.8275862068965517, 0.058823529411764705], 'Precision': [0.8214285714285714, 0.6923076923076923]}
#
# ------
#
#
# Index:  5 balancing: smote
# Accuracy: 0.68
# Params: GaussianNB
# Results: {'Accuracy': [0.8206896551724138, 0.6792452830188679], 'Recall': [0.7793103448275862, 1.0], 'Specificity': [0.8620689655172413, 0.0], 'Precision': [0.849624060150376, 0.6792452830188679]}
#
# ------
#
#
# ('1,None', 0.7142857142857143)
