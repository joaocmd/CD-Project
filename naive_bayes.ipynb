# %%
from strategiesavg import *
from data import *
import matplotlib.pyplot as plt

# Raw
d0 = get_hf_data()
# Outliers
d1 = get_hf_data(filter_outliers=True)
# Scaling
d2 = get_hf_data(scaling='z-score')
d3 = get_hf_data(scaling='minmax')
# Outliers and scaling
d4 = get_hf_data(filter_outliers=True, scaling='z-score')
d5 = get_hf_data(filter_outliers=True, scaling='minmax')

dfs = [d0,d1,d2,d3,d4,d5]
balancings = [None, 'undersample', 'oversample', 'smote']

# %%
best = ("", 0)

for i, df in enumerate(dfs):
    for bal in balancings:
        if (i == 4 or i == 2): continue
        print("Index: ", i, "balancing:", bal)
        params, results = NaiveBayesKFold(df, "DEATH_EVENT", balancing=bal)
        accuracy = results["Accuracy"][1]
        print(f'Accuracy: {accuracy:.2f}')
        print(f'Params: {params}')
        plt.pause(0.1)
        print("Results:", results)
        print("\n------\n\n")
        if (accuracy > best[1]):
            if bal == None: bal = "None"
            best = (str(i) + "," + bal, accuracy)
            
print(best)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 138.52it/s]
# 100%|██████████| 3/3 [00:00<00:00, 284.95it/s]
# 100%|██████████| 3/3 [00:00<00:00, 276.94it/s]
# 100%|██████████| 3/3 [00:00<00:00, 337.67it/s]
# 100%|██████████| 3/3 [00:00<00:00, 282.70it/s]
# Index:  0 balancing: None
# Accuracy: 0.75
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 302.23it/s]
# 100%|██████████| 3/3 [00:00<00:00, 259.32it/s]
# 100%|██████████| 3/3 [00:00<00:00, 237.54it/s]
# 100%|██████████| 3/3 [00:00<00:00, 179.62it/s]
# 100%|██████████| 3/3 [00:00<00:00, 196.06it/s]
# Results: {'Accuracy': [0.8319072524407253, 0.7489265536723164], 'Recall': [0.9458153449973491, 0.8658536585365854], 'Specificity': [0.5914217361585783, 0.49473684210526314], 'Precision': [0.8319011251820599, 0.8199143956176052]}
#
# ------
#
#
# Index:  0 balancing: undersample
# Accuracy: 0.73
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 196.39it/s]
# 100%|██████████| 3/3 [00:00<00:00, 238.11it/s]
# 100%|██████████| 3/3 [00:00<00:00, 210.76it/s]
# 100%|██████████| 3/3 [00:00<00:00, 200.77it/s]
# 100%|██████████| 3/3 [00:00<00:00, 261.71it/s]
# Results: {'Accuracy': [0.8137901572112098, 0.7322598870056497], 'Recall': [0.8775803144224197, 0.7715853658536586], 'Specificity': [0.75, 0.6421052631578947], 'Precision': [0.7815970083047882, 0.8646921363281429]}
#
# ------
#
#
# Index:  0 balancing: oversample
# Accuracy: 0.73
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 212.29it/s]
# 100%|██████████| 3/3 [00:00<00:00, 214.45it/s]
# 100%|██████████| 3/3 [00:00<00:00, 203.27it/s]
# 100%|██████████| 3/3 [00:00<00:00, 181.68it/s]
# 100%|██████████| 3/3 [00:00<00:00, 216.65it/s]
# Results: {'Accuracy': [0.7972998560933121, 0.7289265536723164], 'Recall': [0.8780807392259335, 0.7568292682926829], 'Specificity': [0.7165189729606908, 0.6636842105263158], 'Precision': [0.7597201489361691, 0.8541762633122699]}
#
# ------
#
#
# Index:  0 balancing: smote
# Accuracy: 0.73
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 362.24it/s]
# 100%|██████████| 3/3 [00:00<00:00, 276.44it/s]
# 100%|██████████| 3/3 [00:00<00:00, 318.68it/s]
# 100%|██████████| 3/3 [00:00<00:00, 281.77it/s]
# 100%|██████████| 3/3 [00:00<00:00, 251.19it/s]
# Results: {'Accuracy': [0.809634174051352, 0.7322598870056497], 'Recall': [0.8435507081723851, 0.7371951219512195], 'Specificity': [0.7757176399303188, 0.7157894736842105], 'Precision': [0.7914601561367892, 0.8956725854183482]}
#
# ------
#
#
# Index:  1 balancing: None
# Accuracy: 0.77
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 286.72it/s]
# 100%|██████████| 3/3 [00:00<00:00, 298.63it/s]
# 100%|██████████| 3/3 [00:00<00:00, 257.21it/s]
# 100%|██████████| 3/3 [00:00<00:00, 238.06it/s]
# 100%|██████████| 3/3 [00:00<00:00, 265.02it/s]
# Results: {'Accuracy': [0.8533273556586488, 0.7739348370927318], 'Recall': [0.9273068757145191, 0.8412820512820512], 'Specificity': [0.6867494824016563, 0.6130718954248366], 'Precision': [0.8707311915607924, 0.8672135047764338]}
#
# ------
#
#
# Index:  1 balancing: undersample
# Accuracy: 0.69
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 215.04it/s]
# 100%|██████████| 3/3 [00:00<00:00, 235.63it/s]
# 100%|██████████| 3/3 [00:00<00:00, 215.31it/s]
# 100%|██████████| 3/3 [00:00<00:00, 214.11it/s]
# 100%|██████████| 3/3 [00:00<00:00, 160.60it/s]
# Results: {'Accuracy': [0.8131884057971015, 0.6899122807017544], 'Recall': [0.8217805383022774, 0.6725641025641026], 'Specificity': [0.8045962732919255, 0.7176470588235294], 'Precision': [0.808454574825743, 0.9044648469067074]}
#
# ------
#
#
# Index:  1 balancing: oversample
# Accuracy: 0.71
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 219.27it/s]
# 100%|██████████| 3/3 [00:00<00:00, 207.37it/s]
# 100%|██████████| 3/3 [00:00<00:00, 189.24it/s]
# 100%|██████████| 3/3 [00:00<00:00, 172.43it/s]
# 100%|██████████| 3/3 [00:00<00:00, 217.37it/s]
# Results: {'Accuracy': [0.8009921607055366, 0.7109022556390977], 'Recall': [0.8163073656704231, 0.7083333333333334], 'Specificity': [0.78567695574065, 0.7065359477124183], 'Precision': [0.793447856108139, 0.8966567216567216]}
#
# ------
#
#
# Index:  1 balancing: smote
# Accuracy: 0.72
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 378.32it/s]
# 100%|██████████| 3/3 [00:00<00:00, 300.16it/s]
# 100%|██████████| 3/3 [00:00<00:00, 229.27it/s]
# 100%|██████████| 3/3 [00:00<00:00, 155.02it/s]
# 100%|██████████| 3/3 [00:00<00:00, 228.10it/s]
# Results: {'Accuracy': [0.809276498448473, 0.7180451127819548], 'Recall': [0.7805569165441777, 0.7033333333333334], 'Specificity': [0.8379960803527683, 0.7418300653594772], 'Precision': [0.8288571276147231, 0.9101948051948052]}
#
# ------
#
#
# Index:  3 balancing: None
# Accuracy: 0.76
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 266.31it/s]
# 100%|██████████| 3/3 [00:00<00:00, 338.82it/s]
# 100%|██████████| 3/3 [00:00<00:00, 240.91it/s]
# 100%|██████████| 3/3 [00:00<00:00, 243.73it/s]
# 100%|██████████| 3/3 [00:00<00:00, 212.80it/s]
# Results: {'Accuracy': [0.8009728033472803, 0.762316384180791], 'Recall': [0.9223812769825039, 0.8910975609756098], 'Specificity': [0.5446343130553657, 0.4842105263157895], 'Precision': [0.8116545966632289, 0.8125295680619948]}
#
# ------
#
#
# Index:  3 balancing: undersample
# Accuracy: 0.71
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 135.10it/s]
# 100%|██████████| 3/3 [00:00<00:00, 153.52it/s]
# 100%|██████████| 3/3 [00:00<00:00, 182.67it/s]
# 100%|██████████| 3/3 [00:00<00:00, 187.32it/s]
# 100%|██████████| 3/3 [00:00<00:00, 154.97it/s]
# Results: {'Accuracy': [0.7826042378673957, 0.7123728813559322], 'Recall': [0.8956937799043062, 0.7520731707317073], 'Specificity': [0.6695146958304853, 0.6210526315789474], 'Precision': [0.7322140223417911, 0.8510273922173236]}
#
# ------
#
#
# Index:  3 balancing: oversample
# Accuracy: 0.72
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 190.34it/s]
# 100%|██████████| 3/3 [00:00<00:00, 222.16it/s]
# 100%|██████████| 3/3 [00:00<00:00, 160.30it/s]
# 100%|██████████| 3/3 [00:00<00:00, 160.43it/s]
# 100%|██████████| 3/3 [00:00<00:00, 136.56it/s]
# Results: {'Accuracy': [0.8126865106415209, 0.7189830508474576], 'Recall': [0.8977732333560554, 0.7964634146341464], 'Specificity': [0.7275997879269863, 0.5473684210526316], 'Precision': [0.7715432694442503, 0.8282291374637885]}
#
# ------
#
#
# Index:  3 balancing: smote
# Accuracy: 0.75
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 285.07it/s]
# 100%|██████████| 3/3 [00:00<00:00, 310.48it/s]
# 100%|██████████| 3/3 [00:00<00:00, 201.04it/s]
# 100%|██████████| 3/3 [00:00<00:00, 293.70it/s]
# 100%|██████████| 3/3 [00:00<00:00, 298.82it/s]
# Results: {'Accuracy': [0.8040824055138984, 0.7489830508474576], 'Recall': [0.8891464061198212, 0.8165853658536585], 'Specificity': [0.7190184049079754, 0.6], 'Precision': [0.7622756658091508, 0.8460262725779967]}
#
# ------
#
#
# Index:  5 balancing: None
# Accuracy: 0.69
# Params: MultinomialNB
# 100%|██████████| 3/3 [00:00<00:00, 189.43it/s]
# 100%|██████████| 3/3 [00:00<00:00, 186.15it/s]
# 100%|██████████| 3/3 [00:00<00:00, 249.42it/s]
# 100%|██████████| 3/3 [00:00<00:00, 230.59it/s]
# 100%|██████████| 3/3 [00:00<00:00, 230.63it/s]
# Results: {'Accuracy': [0.6875114105629211, 0.686512928022362], 'Recall': [0.9986206896551724, 1.0], 'Specificity': [0.040248447204968944, 0.03333333333333333], 'Precision': [0.6841077499697713, 0.6830457453098963]}
#
# ------
#
#
# Index:  5 balancing: undersample
# Accuracy: 0.61
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 207.44it/s]
# 100%|██████████| 3/3 [00:00<00:00, 207.39it/s]
# 100%|██████████| 3/3 [00:00<00:00, 195.72it/s]
# 100%|██████████| 3/3 [00:00<00:00, 170.98it/s]
# 100%|██████████| 3/3 [00:00<00:00, 275.05it/s]
# Results: {'Accuracy': [0.7571635610766045, 0.6088050314465409], 'Recall': [0.7788405797101449, 0.6178678678678678], 'Specificity': [0.7354865424430642, 0.5777777777777777], 'Precision': [0.7466506371880723, 0.8268918373524367]}
#
# ------
#
#
# Index:  5 balancing: oversample
# Accuracy: 0.64
# Params: GaussianNB
# 100%|██████████| 3/3 [00:00<00:00, 204.39it/s]
# 100%|██████████| 3/3 [00:00<00:00, 217.11it/s]
# 100%|██████████| 3/3 [00:00<00:00, 190.33it/s]
# 100%|██████████| 3/3 [00:00<00:00, 210.85it/s]
# 100%|██████████| 3/3 [00:00<00:00, 194.42it/s]
# Results: {'Accuracy': [0.7616666666666667, 0.6422082459818309], 'Recall': [0.7775383141762452, 0.6563063063063063], 'Specificity': [0.7457950191570881, 0.6006535947712418], 'Precision': [0.7592646577864394, 0.8486064659977703]}
#
# ------
#
#
# Index:  5 balancing: smote
# Accuracy: 0.63
# Params: MultinomialNB
# Results: {'Accuracy': [0.7271599616858238, 0.6315863032844165], 'Recall': [0.7278352490421456, 0.7181681681681682], 'Specificity': [0.7264846743295019, 0.4444444444444444], 'Precision': [0.7268887018166443, 0.7473302478263442]}
#
# ------
#
#
# ('1,None', 0.7739348370927318)
