# %%
from strategiesavg import *
from data import *
import matplotlib.pyplot as plt

# %%
# Raw
d0 = get_hf_data()
# Outliers
d1 = get_hf_data(filter_outliers=True)
# Scaling
d2 = get_hf_data(scaling='z-score')
d3 = get_hf_data(scaling='minmax')
# Outliers and scaling
d4 = get_hf_data(filter_outliers=True, scaling='z-score')
d5 = get_hf_data(filter_outliers=True, scaling='minmax')

dfs = [d0,d1,d2,d3,d4,d5]
balancings = [None, 'undersample', 'oversample', 'smote']

# %%
best = ("", 0)

for i, df in enumerate(dfs):
    for bal in balancings:
        print("Index: ", i, "balancing:", bal)
        params, results = DecisionTreesKFold(df, "DEATH_EVENT", balancing=bal)
        accuracy = results["Accuracy"][1]
        print(f'Accuracy: {accuracy:.2f}')
        print(f'Params: {params}')
        plt.pause(0.1)
        print("Results:", results)
        print("\n------\n\n")
        if (accuracy > best[1]):
            if bal == None: bal = "None"
            best = (str(i) + "," + bal, accuracy)
            
print(best)
# Out:
#  18%|█▊        | 11/60 [00:00<00:00, 103.91it/s]
# Index:  0 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 169.18it/s]
# 100%|██████████| 60/60 [00:00<00:00, 288.73it/s]
# 100%|██████████| 60/60 [00:00<00:00, 215.75it/s]
# 100%|██████████| 60/60 [00:00<00:00, 217.66it/s]
# 100%|██████████| 60/60 [00:00<00:00, 188.39it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.71
# Params: ('entropy', 5, 0.005)
#  48%|████▊     | 29/60 [00:00<00:00, 288.50it/s]
# Results: {'Accuracy': [0.9625, 0.711864406779661], 'Recall': [0.9815950920245399, 1.0], 'Specificity': [0.922077922077922, 0.10526315789473684], 'Precision': [0.963855421686747, 0.7017543859649122]}
#
# ------
#
#
# Index:  0 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 209.30it/s]
# 100%|██████████| 60/60 [00:00<00:00, 252.88it/s]
# 100%|██████████| 60/60 [00:00<00:00, 254.96it/s]
# 100%|██████████| 60/60 [00:00<00:00, 301.36it/s]
# 100%|██████████| 60/60 [00:00<00:00, 273.71it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
#  38%|███▊      | 23/60 [00:00<00:00, 225.20it/s]
# Results: {'Accuracy': [0.8831168831168831, 0.7457627118644068], 'Recall': [0.8181818181818182, 0.9], 'Specificity': [0.948051948051948, 0.42105263157894735], 'Precision': [0.9402985074626866, 0.7659574468085106]}
#
# ------
#
#
# Index:  0 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 220.02it/s]
# 100%|██████████| 60/60 [00:00<00:00, 231.61it/s]
# 100%|██████████| 60/60 [00:00<00:00, 213.41it/s]
# 100%|██████████| 60/60 [00:00<00:00, 229.00it/s]
# 100%|██████████| 60/60 [00:00<00:00, 206.56it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.68
# Params: ('entropy', 2, 0.025)
#  37%|███▋      | 22/60 [00:00<00:00, 209.97it/s]
# Results: {'Accuracy': [0.8957055214723927, 0.6779661016949152], 'Recall': [0.9202453987730062, 1.0], 'Specificity': [0.8711656441717791, 0.0], 'Precision': [0.8771929824561403, 0.6779661016949152]}
#
# ------
#
#
# Index:  0 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 212.91it/s]
# 100%|██████████| 60/60 [00:00<00:00, 218.82it/s]
# 100%|██████████| 60/60 [00:00<00:00, 205.59it/s]
# 100%|██████████| 60/60 [00:00<00:00, 207.46it/s]
# 100%|██████████| 60/60 [00:00<00:00, 189.78it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 405.21it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8773006134969326, 0.7457627118644068], 'Recall': [0.8220858895705522, 0.85], 'Specificity': [0.9325153374233128, 0.5263157894736842], 'Precision': [0.9241379310344827, 0.7906976744186046]}
#
# ------
#
#
# Index:  1 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 258.76it/s]
# 100%|██████████| 60/60 [00:00<00:00, 409.46it/s]
# 100%|██████████| 60/60 [00:00<00:00, 358.04it/s]
# 100%|██████████| 60/60 [00:00<00:00, 374.45it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.71
# Params: ('entropy', 5, 0.025)
#  55%|█████▌    | 33/60 [00:00<00:00, 323.09it/s]
# Results: {'Accuracy': [0.9074889867841409, 0.7142857142857143], 'Recall': [0.89171974522293, 1.0], 'Specificity': [0.9428571428571428, 0.058823529411764705], 'Precision': [0.9722222222222222, 0.7090909090909091]}
#
# ------
#
#
# Index:  1 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 317.02it/s]
# 100%|██████████| 60/60 [00:00<00:00, 291.95it/s]
# 100%|██████████| 60/60 [00:00<00:00, 274.29it/s]
# 100%|██████████| 60/60 [00:00<00:00, 298.23it/s]
# 100%|██████████| 60/60 [00:00<00:00, 282.92it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.75
# Params: ('gini', 2, 0.025)
#  38%|███▊      | 23/60 [00:00<00:00, 223.85it/s]
# Results: {'Accuracy': [0.8714285714285714, 0.75], 'Recall': [0.8571428571428571, 0.8974358974358975], 'Specificity': [0.8857142857142857, 0.4117647058823529], 'Precision': [0.8823529411764706, 0.7777777777777778]}
#
# ------
#
#
# Index:  1 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 227.67it/s]
# 100%|██████████| 60/60 [00:00<00:00, 220.65it/s]
# 100%|██████████| 60/60 [00:00<00:00, 194.27it/s]
# 100%|██████████| 60/60 [00:00<00:00, 219.45it/s]
# 100%|██████████| 60/60 [00:00<00:00, 220.69it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.75
# Params: ('gini', 2, 0.025)
#  35%|███▌      | 21/60 [00:00<00:00, 204.68it/s]
# Results: {'Accuracy': [0.8726114649681529, 0.75], 'Recall': [0.8535031847133758, 0.8974358974358975], 'Specificity': [0.89171974522293, 0.4117647058823529], 'Precision': [0.8874172185430463, 0.7777777777777778]}
#
# ------
#
#
# Index:  1 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 199.38it/s]
# 100%|██████████| 60/60 [00:00<00:00, 205.49it/s]
# 100%|██████████| 60/60 [00:00<00:00, 172.22it/s]
# 100%|██████████| 60/60 [00:00<00:00, 139.11it/s]
# 100%|██████████| 60/60 [00:00<00:00, 175.28it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 360.88it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8853503184713376, 0.75], 'Recall': [0.8471337579617835, 0.8461538461538461], 'Specificity': [0.9235668789808917, 0.5294117647058824], 'Precision': [0.9172413793103448, 0.8048780487804879]}
#
# ------
#
#
# Index:  2 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 263.88it/s]
# 100%|██████████| 60/60 [00:00<00:00, 344.61it/s]
# 100%|██████████| 60/60 [00:00<00:00, 360.78it/s]
# 100%|██████████| 60/60 [00:00<00:00, 310.77it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.71
# Params: ('entropy', 5, 0.005)
# 100%|██████████| 60/60 [00:00<00:00, 312.13it/s]
# Results: {'Accuracy': [0.9541666666666667, 0.711864406779661], 'Recall': [0.9877300613496932, 1.0], 'Specificity': [0.8831168831168831, 0.10526315789473684], 'Precision': [0.9470588235294117, 0.7017543859649122]}
#
# ------
#
#
# Index:  2 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 291.93it/s]
# 100%|██████████| 60/60 [00:00<00:00, 315.96it/s]
# 100%|██████████| 60/60 [00:00<00:00, 319.16it/s]
# 100%|██████████| 60/60 [00:00<00:00, 275.95it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
#  30%|███       | 18/60 [00:00<00:00, 176.53it/s]
# Results: {'Accuracy': [0.8506493506493507, 0.7457627118644068], 'Recall': [0.7532467532467533, 0.9], 'Specificity': [0.948051948051948, 0.42105263157894735], 'Precision': [0.9354838709677419, 0.7659574468085106]}
#
# ------
#
#
# Index:  2 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 208.05it/s]
# 100%|██████████| 60/60 [00:00<00:00, 172.16it/s]
# 100%|██████████| 60/60 [00:00<00:00, 215.44it/s]
# 100%|██████████| 60/60 [00:00<00:00, 242.47it/s]
# 100%|██████████| 60/60 [00:00<00:00, 224.12it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.75
# Params: ('gini', 2, 0.025)
#  40%|████      | 24/60 [00:00<00:00, 234.85it/s]
# Results: {'Accuracy': [0.8742331288343558, 0.7457627118644068], 'Recall': [0.8466257668711656, 0.9], 'Specificity': [0.901840490797546, 0.42105263157894735], 'Precision': [0.8961038961038961, 0.7659574468085106]}
#
# ------
#
#
# Index:  2 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 223.26it/s]
# 100%|██████████| 60/60 [00:00<00:00, 204.08it/s]
# 100%|██████████| 60/60 [00:00<00:00, 222.66it/s]
# 100%|██████████| 60/60 [00:00<00:00, 214.66it/s]
# 100%|██████████| 60/60 [00:00<00:00, 222.07it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 419.02it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8865030674846626, 0.7457627118644068], 'Recall': [0.8220858895705522, 0.85], 'Specificity': [0.950920245398773, 0.5263157894736842], 'Precision': [0.9436619718309859, 0.7906976744186046]}
#
# ------
#
#
# Index:  3 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 354.96it/s]
# 100%|██████████| 60/60 [00:00<00:00, 377.41it/s]
# 100%|██████████| 60/60 [00:00<00:00, 387.81it/s]
# 100%|██████████| 60/60 [00:00<00:00, 355.24it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.69
# Params: ('entropy', 5, 0.01)
# 100%|██████████| 60/60 [00:00<00:00, 327.42it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.9625, 0.6949152542372882], 'Recall': [0.9815950920245399, 1.0], 'Specificity': [0.922077922077922, 0.05263157894736842], 'Precision': [0.963855421686747, 0.6896551724137931]}
#
# ------
#
#
# Index:  3 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 247.48it/s]
# 100%|██████████| 60/60 [00:00<00:00, 266.92it/s]
# 100%|██████████| 60/60 [00:00<00:00, 199.88it/s]
# 100%|██████████| 60/60 [00:00<00:00, 333.99it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
#  38%|███▊      | 23/60 [00:00<00:00, 225.61it/s]
# Results: {'Accuracy': [0.8831168831168831, 0.7457627118644068], 'Recall': [0.8311688311688312, 0.9], 'Specificity': [0.935064935064935, 0.42105263157894735], 'Precision': [0.927536231884058, 0.7659574468085106]}
#
# ------
#
#
# Index:  3 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 199.71it/s]
# 100%|██████████| 60/60 [00:00<00:00, 217.49it/s]
# 100%|██████████| 60/60 [00:00<00:00, 204.53it/s]
# 100%|██████████| 60/60 [00:00<00:00, 204.24it/s]
# 100%|██████████| 60/60 [00:00<00:00, 213.64it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.69
# Params: ('entropy', 5, 0.001)
#  35%|███▌      | 21/60 [00:00<00:00, 202.18it/s]
# Results: {'Accuracy': [0.9631901840490797, 0.6949152542372882], 'Recall': [0.950920245398773, 0.975], 'Specificity': [0.9754601226993865, 0.10526315789473684], 'Precision': [0.9748427672955975, 0.6964285714285714]}
#
# ------
#
#
# Index:  3 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 204.42it/s]
# 100%|██████████| 60/60 [00:00<00:00, 150.17it/s]
# 100%|██████████| 60/60 [00:00<00:00, 179.84it/s]
# 100%|██████████| 60/60 [00:00<00:00, 215.29it/s]
# 100%|██████████| 60/60 [00:00<00:00, 222.80it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.68
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 419.54it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8895705521472392, 0.6779661016949152], 'Recall': [0.9202453987730062, 1.0], 'Specificity': [0.8588957055214724, 0.0], 'Precision': [0.8670520231213873, 0.6779661016949152]}
#
# ------
#
#
# Index:  4 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 333.59it/s]
# 100%|██████████| 60/60 [00:00<00:00, 342.59it/s]
# 100%|██████████| 60/60 [00:00<00:00, 395.56it/s]
# 100%|██████████| 60/60 [00:00<00:00, 407.61it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.68
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 335.77it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8744186046511628, 0.6792452830188679], 'Recall': [0.9103448275862069, 1.0], 'Specificity': [0.8, 0.0], 'Precision': [0.9041095890410958, 0.6792452830188679]}
#
# ------
#
#
# Index:  4 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 312.80it/s]
# 100%|██████████| 60/60 [00:00<00:00, 317.05it/s]
# 100%|██████████| 60/60 [00:00<00:00, 352.06it/s]
# 100%|██████████| 60/60 [00:00<00:00, 330.47it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.70
# Params: ('gini', 20, 0.0025)
#  43%|████▎     | 26/60 [00:00<00:00, 246.73it/s]
# Results: {'Accuracy': [0.9928571428571429, 0.6981132075471698], 'Recall': [0.9857142857142858, 0.9444444444444444], 'Specificity': [1.0, 0.17647058823529413], 'Precision': [1.0, 0.7083333333333334]}
#
# ------
#
#
# Index:  4 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 228.46it/s]
# 100%|██████████| 60/60 [00:00<00:00, 229.07it/s]
# 100%|██████████| 60/60 [00:00<00:00, 248.55it/s]
# 100%|██████████| 60/60 [00:00<00:00, 259.28it/s]
# 100%|██████████| 60/60 [00:00<00:00, 251.29it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.68
# Params: ('entropy', 2, 0.025)
#  42%|████▏     | 25/60 [00:00<00:00, 237.31it/s]
# Results: {'Accuracy': [0.8551724137931035, 0.6792452830188679], 'Recall': [0.9103448275862069, 1.0], 'Specificity': [0.8, 0.0], 'Precision': [0.8198757763975155, 0.6792452830188679]}
#
# ------
#
#
# Index:  4 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 230.14it/s]
# 100%|██████████| 60/60 [00:00<00:00, 218.44it/s]
# 100%|██████████| 60/60 [00:00<00:00, 239.61it/s]
# 100%|██████████| 60/60 [00:00<00:00, 232.67it/s]
# 100%|██████████| 60/60 [00:00<00:00, 233.66it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.70
# Params: ('entropy', 5, 0.01)
# 100%|██████████| 60/60 [00:00<00:00, 386.08it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8896551724137931, 0.6981132075471698], 'Recall': [0.8206896551724138, 1.0], 'Specificity': [0.9586206896551724, 0.058823529411764705], 'Precision': [0.952, 0.6923076923076923]}
#
# ------
#
#
# Index:  5 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 354.81it/s]
# 100%|██████████| 60/60 [00:00<00:00, 401.54it/s]
# 100%|██████████| 60/60 [00:00<00:00, 422.48it/s]
# 100%|██████████| 60/60 [00:00<00:00, 355.56it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.68
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 345.03it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8744186046511628, 0.6792452830188679], 'Recall': [0.9103448275862069, 1.0], 'Specificity': [0.8, 0.0], 'Precision': [0.9041095890410958, 0.6792452830188679]}
#
# ------
#
#
# Index:  5 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 313.80it/s]
# 100%|██████████| 60/60 [00:00<00:00, 327.09it/s]
# 100%|██████████| 60/60 [00:00<00:00, 336.21it/s]
# 100%|██████████| 60/60 [00:00<00:00, 311.75it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.72
# Params: ('entropy', 5, 0.025)
#  43%|████▎     | 26/60 [00:00<00:00, 255.29it/s]
# Results: {'Accuracy': [0.8642857142857143, 0.7169811320754716], 'Recall': [0.7285714285714285, 1.0], 'Specificity': [1.0, 0.11764705882352941], 'Precision': [1.0, 0.7058823529411765]}
#
# ------
#
#
# Index:  5 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 243.50it/s]
# 100%|██████████| 60/60 [00:00<00:00, 244.23it/s]
# 100%|██████████| 60/60 [00:00<00:00, 241.52it/s]
# 100%|██████████| 60/60 [00:00<00:00, 246.80it/s]
# 100%|██████████| 60/60 [00:00<00:00, 248.97it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.72
# Params: ('gini', 5, 0.0025)
#  42%|████▏     | 25/60 [00:00<00:00, 246.56it/s]
# Results: {'Accuracy': [0.9517241379310345, 0.7169811320754716], 'Recall': [0.9517241379310345, 0.9722222222222222], 'Specificity': [0.9517241379310345, 0.17647058823529413], 'Precision': [0.9517241379310345, 0.7142857142857143]}
#
# ------
#
#
# Index:  5 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 228.16it/s]
# 100%|██████████| 60/60 [00:00<00:00, 229.74it/s]
# 100%|██████████| 60/60 [00:00<00:00, 218.35it/s]
# 100%|██████████| 60/60 [00:00<00:00, 213.53it/s]
# 100%|██████████| 60/60 [00:00<00:00, 212.00it/s]
# min_impurity_decrease, max_depth, criteria
# Accuracy: 0.70
# Params: ('entropy', 10, 0.01)
# Results: {'Accuracy': [0.9827586206896551, 0.6981132075471698], 'Recall': [0.9724137931034482, 1.0], 'Specificity': [0.993103448275862, 0.058823529411764705], 'Precision': [0.9929577464788732, 0.6923076923076923]}
#
# ------
#
#
# ('1,undersample', 0.75)
