# %%
from strategiesavg import *
from data import *
import matplotlib.pyplot as plt

# %%
# Raw
d0 = get_hf_data()
# Outliers
d1 = get_hf_data(filter_outliers=True)
# Scaling
d2 = get_hf_data(scaling='z-score')
d3 = get_hf_data(scaling='minmax')
# Outliers and scaling
d4 = get_hf_data(filter_outliers=True, scaling='z-score')
d5 = get_hf_data(filter_outliers=True, scaling='minmax')

dfs = [d0,d1,d2,d3,d4,d5]
balancings = [None, 'undersample', 'oversample', 'smote']

# %%
best = ("", 0)

for i, df in enumerate(dfs):
    for bal in balancings:
        print("Index: ", i, "balancing:", bal)
        params, results = DecisionTreesKFold(df, "DEATH_EVENT", balancing=bal)
        accuracy = results["Accuracy"][1]
        print(f'Accuracy: {accuracy:.2f}')
        print(f'Params: {params}')
        plt.pause(0.1)
        print("Results:", results)
        print("\n------\n\n")
        if (accuracy > best[1]):
            if bal == None: bal = "None"
            best = (str(i) + "," + bal, accuracy)
            
print(best)
# Out:
#   0%|          | 0/150 [1:05:45<?, ?it/s]
#
#
#
# 100%|██████████| 60/60 [00:00<00:00, 547.44it/s]
#
#   0%|          | 0/60 [00:00<?, ?it/s]
# Index:  0 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 597.17it/s]
#
#   0%|          | 0/60 [00:00<?, ?it/s]
# 100%|██████████| 60/60 [00:00<00:00, 575.57it/s]
#
# 100%|██████████| 60/60 [00:00<00:00, 610.66it/s]
#
# 100%|██████████| 60/60 [00:00<00:00, 637.61it/s]
#   0%|          | 0/150 [1:05:55<?, ?it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.71
# Params: ('entropy', 10, 0.005)
# 100%|██████████| 60/60 [00:00<00:00, 421.95it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [1.0, 0.711864406779661], 'Recall': [1.0, 1.0], 'Specificity': [1.0, 0.10526315789473684], 'Precision': [1.0, 0.7017543859649122]}
#
# ------
#
#
# Index:  0 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 441.01it/s]
# 100%|██████████| 60/60 [00:00<00:00, 470.04it/s]
# 100%|██████████| 60/60 [00:00<00:00, 500.45it/s]
# 100%|██████████| 60/60 [00:00<00:00, 473.12it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.71
# Params: ('entropy', 5, 0.005)
#  43%|████▎     | 26/60 [00:00<00:00, 259.50it/s]
# Results: {'Accuracy': [0.9805194805194806, 0.711864406779661], 'Recall': [0.987012987012987, 1.0], 'Specificity': [0.974025974025974, 0.10526315789473684], 'Precision': [0.9743589743589743, 0.7017543859649122]}
#
# ------
#
#
# Index:  0 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 311.90it/s]
# 100%|██████████| 60/60 [00:00<00:00, 324.99it/s]
# 100%|██████████| 60/60 [00:00<00:00, 325.02it/s]
# 100%|██████████| 60/60 [00:00<00:00, 361.88it/s]
# 100%|██████████| 60/60 [00:00<00:00, 367.23it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
#  50%|█████     | 30/60 [00:00<00:00, 294.65it/s]
# Results: {'Accuracy': [0.8803680981595092, 0.7457627118644068], 'Recall': [0.8282208588957055, 0.9], 'Specificity': [0.9325153374233128, 0.42105263157894735], 'Precision': [0.9246575342465754, 0.7659574468085106]}
#
# ------
#
#
# Index:  0 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 320.10it/s]
# 100%|██████████| 60/60 [00:00<00:00, 304.00it/s]
# 100%|██████████| 60/60 [00:00<00:00, 316.98it/s]
# 100%|██████████| 60/60 [00:00<00:00, 326.72it/s]
# 100%|██████████| 60/60 [00:00<00:00, 337.14it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 526.35it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8773006134969326, 0.7457627118644068], 'Recall': [0.8220858895705522, 0.85], 'Specificity': [0.9325153374233128, 0.5263157894736842], 'Precision': [0.9241379310344827, 0.7906976744186046]}
#
# ------
#
#
# Index:  1 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 570.23it/s]
# 100%|██████████| 60/60 [00:00<00:00, 581.07it/s]
# 100%|██████████| 60/60 [00:00<00:00, 641.92it/s]
# 100%|██████████| 60/60 [00:00<00:00, 622.01it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.71
# Params: ('entropy', 10, 0.01)
# 100%|██████████| 60/60 [00:00<00:00, 418.97it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.9911894273127754, 0.7142857142857143], 'Recall': [0.9872611464968153, 1.0], 'Specificity': [1.0, 0.058823529411764705], 'Precision': [1.0, 0.7090909090909091]}
#
# ------
#
#
# Index:  1 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 347.48it/s]
# 100%|██████████| 60/60 [00:00<00:00, 514.24it/s]
# 100%|██████████| 60/60 [00:00<00:00, 512.20it/s]
# 100%|██████████| 60/60 [00:00<00:00, 525.96it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('gini', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 366.08it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8785714285714286, 0.75], 'Recall': [0.8714285714285714, 0.8974358974358975], 'Specificity': [0.8857142857142857, 0.4117647058823529], 'Precision': [0.8840579710144928, 0.7777777777777778]}
#
# ------
#
#
# Index:  1 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 359.27it/s]
# 100%|██████████| 60/60 [00:00<00:00, 331.10it/s]
# 100%|██████████| 60/60 [00:00<00:00, 359.70it/s]
# 100%|██████████| 60/60 [00:00<00:00, 349.59it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 324.85it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.89171974522293, 0.75], 'Recall': [0.8535031847133758, 0.8974358974358975], 'Specificity': [0.9299363057324841, 0.4117647058823529], 'Precision': [0.9241379310344827, 0.7777777777777778]}
#
# ------
#
#
# Index:  1 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 311.47it/s]
# 100%|██████████| 60/60 [00:00<00:00, 330.32it/s]
# 100%|██████████| 60/60 [00:00<00:00, 331.53it/s]
# 100%|██████████| 60/60 [00:00<00:00, 338.17it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 468.28it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8853503184713376, 0.75], 'Recall': [0.8471337579617835, 0.8461538461538461], 'Specificity': [0.9235668789808917, 0.5294117647058824], 'Precision': [0.9172413793103448, 0.8048780487804879]}
#
# ------
#
#
# Index:  2 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 562.47it/s]
# 100%|██████████| 60/60 [00:00<00:00, 562.75it/s]
# 100%|██████████| 60/60 [00:00<00:00, 623.04it/s]
# 100%|██████████| 60/60 [00:00<00:00, 629.31it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.71
# Params: ('entropy', 5, 0.01)
# 100%|██████████| 60/60 [00:00<00:00, 420.28it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.9625, 0.711864406779661], 'Recall': [0.9815950920245399, 1.0], 'Specificity': [0.922077922077922, 0.10526315789473684], 'Precision': [0.963855421686747, 0.7017543859649122]}
#
# ------
#
#
# Index:  2 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 491.61it/s]
# 100%|██████████| 60/60 [00:00<00:00, 500.38it/s]
# 100%|██████████| 60/60 [00:00<00:00, 502.65it/s]
# 100%|██████████| 60/60 [00:00<00:00, 495.78it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 357.21it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8766233766233766, 0.7457627118644068], 'Recall': [0.8181818181818182, 0.9], 'Specificity': [0.935064935064935, 0.42105263157894735], 'Precision': [0.9264705882352942, 0.7659574468085106]}
#
# ------
#
#
# Index:  2 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 339.39it/s]
# 100%|██████████| 60/60 [00:00<00:00, 328.08it/s]
# 100%|██████████| 60/60 [00:00<00:00, 351.40it/s]
# 100%|██████████| 60/60 [00:00<00:00, 365.56it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('gini', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 324.64it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8957055214723927, 0.7457627118644068], 'Recall': [0.8650306748466258, 0.95], 'Specificity': [0.9263803680981595, 0.3157894736842105], 'Precision': [0.9215686274509803, 0.7450980392156863]}
#
# ------
#
#
# Index:  2 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 319.28it/s]
# 100%|██████████| 60/60 [00:00<00:00, 325.93it/s]
# 100%|██████████| 60/60 [00:00<00:00, 313.65it/s]
# 100%|██████████| 60/60 [00:00<00:00, 340.43it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 455.52it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8865030674846626, 0.7457627118644068], 'Recall': [0.8220858895705522, 0.85], 'Specificity': [0.950920245398773, 0.5263157894736842], 'Precision': [0.9436619718309859, 0.7906976744186046]}
#
# ------
#
#
# Index:  3 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 501.46it/s]
# 100%|██████████| 60/60 [00:00<00:00, 589.34it/s]
# 100%|██████████| 60/60 [00:00<00:00, 644.77it/s]
# 100%|██████████| 60/60 [00:00<00:00, 631.81it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.69
# Params: ('entropy', 5, 0.01)
# 100%|██████████| 60/60 [00:00<00:00, 409.17it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.9625, 0.6949152542372882], 'Recall': [0.9815950920245399, 1.0], 'Specificity': [0.922077922077922, 0.05263157894736842], 'Precision': [0.963855421686747, 0.6896551724137931]}
#
# ------
#
#
# Index:  3 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 430.52it/s]
# 100%|██████████| 60/60 [00:00<00:00, 486.55it/s]
# 100%|██████████| 60/60 [00:00<00:00, 485.75it/s]
# 100%|██████████| 60/60 [00:00<00:00, 508.13it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('gini', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 358.17it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8766233766233766, 0.7457627118644068], 'Recall': [0.8181818181818182, 0.9], 'Specificity': [0.935064935064935, 0.42105263157894735], 'Precision': [0.9264705882352942, 0.7659574468085106]}
#
# ------
#
#
# Index:  3 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 336.17it/s]
# 100%|██████████| 60/60 [00:00<00:00, 353.44it/s]
# 100%|██████████| 60/60 [00:00<00:00, 366.55it/s]
# 100%|██████████| 60/60 [00:00<00:00, 333.60it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.75
# Params: ('gini', 2, 0.025)
#  47%|████▋     | 28/60 [00:00<00:00, 277.45it/s]
# Results: {'Accuracy': [0.8680981595092024, 0.7457627118644068], 'Recall': [0.8282208588957055, 0.9], 'Specificity': [0.9079754601226994, 0.42105263157894735], 'Precision': [0.9, 0.7659574468085106]}
#
# ------
#
#
# Index:  3 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 318.09it/s]
# 100%|██████████| 60/60 [00:00<00:00, 315.82it/s]
# 100%|██████████| 60/60 [00:00<00:00, 295.61it/s]
# 100%|██████████| 60/60 [00:00<00:00, 338.13it/s]
# 100%|██████████| 60/60 [00:00<00:00, 331.99it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.68
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 565.90it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8895705521472392, 0.6779661016949152], 'Recall': [0.9202453987730062, 1.0], 'Specificity': [0.8588957055214724, 0.0], 'Precision': [0.8670520231213873, 0.6779661016949152]}
#
# ------
#
#
# Index:  4 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 387.44it/s]
# 100%|██████████| 60/60 [00:00<00:00, 576.31it/s]
# 100%|██████████| 60/60 [00:00<00:00, 642.12it/s]
# 100%|██████████| 60/60 [00:00<00:00, 645.00it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.68
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 481.07it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8744186046511628, 0.6792452830188679], 'Recall': [0.9103448275862069, 1.0], 'Specificity': [0.8, 0.0], 'Precision': [0.9041095890410958, 0.6792452830188679]}
#
# ------
#
#
# Index:  4 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 478.61it/s]
# 100%|██████████| 60/60 [00:00<00:00, 517.03it/s]
# 100%|██████████| 60/60 [00:00<00:00, 544.08it/s]
# 100%|██████████| 60/60 [00:00<00:00, 526.84it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.72
# Params: ('gini', 5, 0.01)
# 100%|██████████| 60/60 [00:00<00:00, 338.48it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8857142857142857, 0.7169811320754716], 'Recall': [0.9142857142857143, 1.0], 'Specificity': [0.8571428571428571, 0.11764705882352941], 'Precision': [0.8648648648648649, 0.7058823529411765]}
#
# ------
#
#
# Index:  4 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 370.15it/s]
# 100%|██████████| 60/60 [00:00<00:00, 373.80it/s]
# 100%|██████████| 60/60 [00:00<00:00, 412.64it/s]
# 100%|██████████| 60/60 [00:00<00:00, 395.20it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.70
# Params: ('entropy', 5, 0.01)
# 100%|██████████| 60/60 [00:00<00:00, 313.82it/s]
# Results: {'Accuracy': [0.9103448275862069, 0.6981132075471698], 'Recall': [0.8344827586206897, 1.0], 'Specificity': [0.9862068965517241, 0.058823529411764705], 'Precision': [0.983739837398374, 0.6923076923076923]}
#
# ------
#
#
# Index:  4 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 324.65it/s]
# 100%|██████████| 60/60 [00:00<00:00, 339.75it/s]
# 100%|██████████| 60/60 [00:00<00:00, 350.14it/s]
# 100%|██████████| 60/60 [00:00<00:00, 329.22it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.70
# Params: ('entropy', 5, 0.01)
# 100%|██████████| 60/60 [00:00<00:00, 571.44it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.896551724137931, 0.6981132075471698], 'Recall': [0.8344827586206897, 1.0], 'Specificity': [0.9586206896551724, 0.058823529411764705], 'Precision': [0.952755905511811, 0.6923076923076923]}
#
# ------
#
#
# Index:  5 balancing: None
# 100%|██████████| 60/60 [00:00<00:00, 583.56it/s]
# 100%|██████████| 60/60 [00:00<00:00, 613.67it/s]
# 100%|██████████| 60/60 [00:00<00:00, 674.32it/s]
# 100%|██████████| 60/60 [00:00<00:00, 665.83it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.68
# Params: ('entropy', 2, 0.025)
# 100%|██████████| 60/60 [00:00<00:00, 416.13it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.8744186046511628, 0.6792452830188679], 'Recall': [0.9103448275862069, 1.0], 'Specificity': [0.8, 0.0], 'Precision': [0.9041095890410958, 0.6792452830188679]}
#
# ------
#
#
# Index:  5 balancing: undersample
# 100%|██████████| 60/60 [00:00<00:00, 506.96it/s]
# 100%|██████████| 60/60 [00:00<00:00, 509.07it/s]
# 100%|██████████| 60/60 [00:00<00:00, 542.52it/s]
# 100%|██████████| 60/60 [00:00<00:00, 516.44it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.70
# Params: ('gini', 20, 0.005)
# 100%|██████████| 60/60 [00:00<00:00, 343.42it/s]
#   0%|          | 0/60 [00:00<?, ?it/s]
# Results: {'Accuracy': [0.9857142857142858, 0.6981132075471698], 'Recall': [1.0, 1.0], 'Specificity': [0.9714285714285714, 0.058823529411764705], 'Precision': [0.9722222222222222, 0.6923076923076923]}
#
# ------
#
#
# Index:  5 balancing: oversample
# 100%|██████████| 60/60 [00:00<00:00, 339.45it/s]
# 100%|██████████| 60/60 [00:00<00:00, 370.04it/s]
# 100%|██████████| 60/60 [00:00<00:00, 360.72it/s]
# 100%|██████████| 60/60 [00:00<00:00, 357.97it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.70
# Params: ('entropy', 10, 0.01)
#  43%|████▎     | 26/60 [00:00<00:00, 255.62it/s]
# Results: {'Accuracy': [0.996551724137931, 0.6981132075471698], 'Recall': [0.993103448275862, 1.0], 'Specificity': [1.0, 0.058823529411764705], 'Precision': [1.0, 0.6923076923076923]}
#
# ------
#
#
# Index:  5 balancing: smote
# 100%|██████████| 60/60 [00:00<00:00, 313.25it/s]
# 100%|██████████| 60/60 [00:00<00:00, 355.92it/s]
# 100%|██████████| 60/60 [00:00<00:00, 347.45it/s]
# 100%|██████████| 60/60 [00:00<00:00, 355.82it/s]
# 100%|██████████| 60/60 [00:00<00:00, 359.06it/s]
# criteria, max_depth, min_impurity_decrease
# Accuracy: 0.70
# Params: ('entropy', 15, 0.01)
# Results: {'Accuracy': [0.993103448275862, 0.6981132075471698], 'Recall': [0.993103448275862, 1.0], 'Specificity': [0.993103448275862, 0.058823529411764705], 'Precision': [0.993103448275862, 0.6923076923076923]}
#
# ------
#
#
# ('1,undersample', 0.75)
